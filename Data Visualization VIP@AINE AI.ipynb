# %% [markdown]
# # VIP@ AINE AI

# %% [markdown]
# # Data Manipulation and Visualization using Python

# %% [markdown]
# ### Submitted by Srishti Todi

# %% [markdown]
# # About the Project
#
# This project is more of a training module which helps you understand how data manipulation and visualization can be done on Python. It will take multiple smaller datasets or will create dataframes to teach important concepts that we use in common data manipulation and visualization.
#
# The project will be focused around the use of Pandas and MatPlotLib libraries of Python programming. In a professional setting, you would work on larger datasets however, the same concepts are going to be applied on smaller datasets in this project.

# %% [markdown]
# # How to work on this project
#
# Since it is more of a training module, you are required to read the concepts and concepts written and follow the instructions to answer the questions or get desired output.
#
# Suggested resources and links are mentioned in the Notebook for certain concepts. You can open the links and read/watch the content to get an understanding of the concepts.

# %% [markdown]
# # Pandas in Python
#
# Pandas is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.
#
# When the values are in a table, the table in Python programming is called a dataframe.
# Basically, dataframes are nothing but variables with values in structured data format.
#
# Pandas library is used to view, manipulate (modify) and analyse dataframes which are 2-D or 3-D in nature.

# %% [markdown]
# # Matplotlib in Python
#
# Matplotlib is a plotting library in Python. It is used for creating static, animated, and interactive visualizations in Python.
# In this project, we will use some modules of matplotlib library to create line, bar, column and pie charts with customized formatting to visualize certain data.

# %%
#importing the required libraries
import pandas as pd                       
import matplotlib.pyplot as plt

# %%
brics=pd.read_csv("C:/Users/srish/Downloads/brics.csv") #loading the dataset

# %%
brics       #displaying the dataframe
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %%
print(brics)            #using print function to display dataframe
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# ### We can see a difference if we use print(dataframe) and if we don't use print function as in the former case we cannot see a tabular form unlike in the latter case.

# %%
# Data type of any variable can be seen using the function type()

print(type(5))
print(type('a text'))
print(type(True))
print(type(brics))         # datatype of the dataframe created above
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## Exploring the dataframe

# %%
'''
The info() function is used to print a concise summary of a DataFrame. 
This method prints information about a DataFrame including the index dtype and column dtypes, 
non-null values and memory usage.
'''
brics.info()  #Exploring the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   code        5 non-null      object
#  1   country     5 non-null      object
#  2   population  5 non-null      int64
#  3   area        5 non-null      int64
#  4   capital     5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 328.0+ bytes

# %%
#value_counts() function returns object containing counts of unique values. 
#The resulting object will be in descending order so that the first element is the most frequently-occurring element. 
#Excludes NA values by default.

brics.value_counts("country")
# Out:
# country
# South Africa    1
# Russia          1
# India           1
# China           1
# Brazil          1
# dtype: int64

# %%
brics.value_counts("population")
# Out:
# population
# 1357    1
# 1252    1
# 200     1
# 144     1
# 55      1
# dtype: int64

# %%
#Arranaging the data in ascending order
brics.sort_values(by=["population"])  #Ascending by default
# Out:
#   code       country  population      area    capital
# 4   SA  South Africa          55   1221037   Pretoria
# 1   RU        Russia         144  17098242     Moscow
# 0   BR        Brazil         200   8515767   Brasilia
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing

# %%
brics.sort_values(by=["population"],ascending=True)   #By specifying the order
# Out:
#   code       country  population      area    capital
# 4   SA  South Africa          55   1221037   Pretoria
# 1   RU        Russia         144  17098242     Moscow
# 0   BR        Brazil         200   8515767   Brasilia
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing

# %%
#Sorting the data in descending order
brics.sort_values(by=["population"], ascending=False)    #Remember, we cannot use descending =True as it is not valid
# Out:
#   code       country  population      area    capital
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %%
#Do you think sorting the data changes the data in original dataframe?
brics
# Out:
#   code       country  population      area    capital
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 2   IN         India        1252   3287590  New Delhi
# 3   CH         China        1357   9596961    Beijing
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# ### Thus we can see that  sorting the data has no effect on the original dataframe

# %%
# TO DO: Sort the data to see which country has largest population ( population is in millions).
#We can sort the data in descending order by population to find the required value
brics.sort_values(by=["population"],ascending=False)
# Out:
#   code       country  population      area    capital
# 3   CH         China        1357   9596961    Beijing
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 1   RU        Russia         144  17098242     Moscow
# 4   SA  South Africa          55   1221037   Pretoria

# %% [markdown]
# ### Thus, we can see that China has the largest population with a population of 1357 millions.

# %%
# TO DO: Sort the data to see which country is smallest in size.
# We can sort the data in ascending order by area to find the required value.
brics.sort_values(by=["area"])
# Out:
#   code       country  population      area    capital
# 4   SA  South Africa          55   1221037   Pretoria
# 2   IN         India        1252   3287590  New Delhi
# 0   BR        Brazil         200   8515767   Brasilia
# 3   CH         China        1357   9596961    Beijing
# 1   RU        Russia         144  17098242     Moscow

# %% [markdown]
# ### We can see that South Africa is the smallest country in size.

# %%
# Sorting and printing just one column.
brics.country.sort_values(ascending=False)
# Out:
# 4    South Africa
# 1          Russia
# 2           India
# 3           China
# 0          Brazil
# Name: country, dtype: object

# %%
# TO DO: Sort and print area column on from largest to smallest.
brics.area.sort_values(ascending=False)
# Out:
# 1    17098242
# 3     9596961
# 0     8515767
# 2     3287590
# 4     1221037
# Name: area, dtype: int64

# %% [markdown]
# ## Indexing in dataframes

# %%
# Indices can be used to fetch data from a particular row. 
# Example, to fetch data from the 2nd row, we can use index 1 (one)
brics.country[1]

# We will work more on the index column later.
# Out:
# 'Russia'

# %%
# Getting single column from a dataframe
print(brics["country"])
# Out:
# 0          Brazil
# 1          Russia
# 2           India
# 3           China
# 4    South Africa
# Name: country, dtype: object

# %%
# TO DO: Print area column from brics dataframe
print(brics["area"])
# Out:
# 0     8515767
# 1    17098242
# 2     3287590
# 3     9596961
# 4     1221037
# Name: area, dtype: int64

# %%
# Other way to get a single column from a dataframe - use dot
brics.country
# Out:
# 0          Brazil
# 1          Russia
# 2           India
# 3           China
# 4    South Africa
# Name: country, dtype: object

# %%
# TO DO:  Print code column from the dataframe using dot
brics.code
# Out:
# 0    BR
# 1    RU
# 2    IN
# 3    CH
# 4    SA
# Name: code, dtype: object

# %%
# Pritning multiple columns
brics[['country', 'capital']]
# Out:
#         country    capital
# 0        Brazil   Brasilia
# 1        Russia     Moscow
# 2         India  New Delhi
# 3         China    Beijing
# 4  South Africa   Pretoria

# %%
# TO DO: Print country, capital and population
brics[["country","capital","population"]]
# Out:
#         country    capital  population
# 0        Brazil   Brasilia         200
# 1        Russia     Moscow         144
# 2         India  New Delhi        1252
# 3         China    Beijing        1357
# 4  South Africa   Pretoria          55

# %%
df = pd.DataFrame({'name': ['Niko', 'Penelope', 'Aria'],
                   'average score': [10, 5, 3],
                   'max': [99, 100, 3]})
                   
df
# Out:
#        name  average score  max
# 0      Niko             10   99
# 1  Penelope              5  100
# 2      Aria              3    3

# %%
df.average score    #it will show an error as there is no square bracket
# Out:
#   File "<ipython-input-26-a815afb39ad8>", line 1
#     df.average score    #it will show an error as there is no square bracket
#                ^
# SyntaxError: invalid syntax

# %%
df["average score"]           #Since we have used square bracket here, it will not show any error
# Out:
# 0    10
# 1     5
# 2     3
# Name: average score, dtype: int64

# %%
brics=pd.read_csv("C:/Users/srish/Downloads/brics.csv", index_col=0)
brics
# Out:
#            country  population      area    capital
# code
# BR          Brazil         200   8515767   Brasilia
# RU          Russia         144  17098242     Moscow
# IN           India        1252   3287590  New Delhi
# CH           China        1357   9596961    Beijing
# SA    South Africa          55   1221037   Pretoria

# %% [markdown]
# ## Transforming the dataframe

# %%
#Adding a new column to the existing Data Frame
brics["on_earth"] = [True, True, True, True, True]    
brics
# Out:
#            country  population      area    capital  on_earth
# code
# BR          Brazil         200   8515767   Brasilia      True
# RU          Russia         144  17098242     Moscow      True
# IN           India        1252   3287590  New Delhi      True
# CH           China        1357   9596961    Beijing      True
# SA    South Africa          55   1221037   Pretoria      True

# %%
# adding a calculated column
brics["density"] = brics["population"] / brics["area"] * 1000000   # per km sq.
brics
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680

# %%
#Removing the additional decimal points or setting the precision can be done on the entire dataframe.
brics.style.set_precision(2)       # Upto 2 decimal points for all float columns in the dataframe. 
# This WILL NOT change the original dataframe i.e. the original dataframe will still have multiple digits after decimals.
# Out:
# <style  type="text/css" >
# </style><table id="T_01abaa48_044a_11ec_897f_d8d0905f8c2c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >population</th>        <th class="col_heading level0 col2" >area</th>        <th class="col_heading level0 col3" >capital</th>        <th class="col_heading level0 col4" >on_earth</th>        <th class="col_heading level0 col5" >density</th>    </tr>    <tr>        <th class="index_name level0" >code</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_01abaa48_044a_11ec_897f_d8d0905f8c2clevel0_row0" class="row_heading level0 row0" >BR</th>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow0_col0" class="data row0 col0" >Brazil</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow0_col1" class="data row0 col1" >200</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow0_col2" class="data row0 col2" >8515767</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow0_col3" class="data row0 col3" >Brasilia</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow0_col4" class="data row0 col4" >True</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow0_col5" class="data row0 col5" >23.49</td>
#             </tr>
#             <tr>
#                         <th id="T_01abaa48_044a_11ec_897f_d8d0905f8c2clevel0_row1" class="row_heading level0 row1" >RU</th>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow1_col0" class="data row1 col0" >Russia</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow1_col1" class="data row1 col1" >144</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow1_col2" class="data row1 col2" >17098242</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow1_col3" class="data row1 col3" >Moscow</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow1_col4" class="data row1 col4" >True</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow1_col5" class="data row1 col5" >8.42</td>
#             </tr>
#             <tr>
#                         <th id="T_01abaa48_044a_11ec_897f_d8d0905f8c2clevel0_row2" class="row_heading level0 row2" >IN</th>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow2_col0" class="data row2 col0" >India</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow2_col1" class="data row2 col1" >1252</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow2_col2" class="data row2 col2" >3287590</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow2_col3" class="data row2 col3" >New Delhi</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow2_col4" class="data row2 col4" >True</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow2_col5" class="data row2 col5" >380.83</td>
#             </tr>
#             <tr>
#                         <th id="T_01abaa48_044a_11ec_897f_d8d0905f8c2clevel0_row3" class="row_heading level0 row3" >CH</th>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow3_col0" class="data row3 col0" >China</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow3_col1" class="data row3 col1" >1357</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow3_col2" class="data row3 col2" >9596961</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow3_col3" class="data row3 col3" >Beijing</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow3_col4" class="data row3 col4" >True</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow3_col5" class="data row3 col5" >141.40</td>
#             </tr>
#             <tr>
#                         <th id="T_01abaa48_044a_11ec_897f_d8d0905f8c2clevel0_row4" class="row_heading level0 row4" >SA</th>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow4_col0" class="data row4 col0" >South Africa</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow4_col1" class="data row4 col1" >55</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow4_col2" class="data row4 col2" >1221037</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow4_col3" class="data row4 col3" >Pretoria</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow4_col4" class="data row4 col4" >True</td>
#                         <td id="T_01abaa48_044a_11ec_897f_d8d0905f8c2crow4_col5" class="data row4 col5" >45.04</td>
#             </tr>
#     </tbody></table>

# %%
brics['density'].round(2)   #Rounding of individual column to fixed decimal points.
# Out:
# code
# BR     23.49
# RU      8.42
# IN    380.83
# CH    141.40
# SA     45.04
# Name: density, dtype: float64

# %% [markdown]
# # Fetching data using indices and location functions (.loc and .iloc)
#
# To Note:
# 1. .loc is used with the actual value/label of the index
# 2. .iloc is used with the index position/reference - which are numbers (0, 1, 2, 3, 4......)

# %%
brics
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680

# %%
brics.loc["SA"]
# Out:
# country       South Africa
# population              55
# area               1221037
# capital           Pretoria
# on_earth              True
# density            45.0437
# Name: SA, dtype: object

# %%
brics.iloc[4]
# Out:
# country       South Africa
# population              55
# area               1221037
# capital           Pretoria
# on_earth              True
# density            45.0437
# Name: SA, dtype: object

# %%
# TO DO: Use .loc to print the values from all columns for IN
brics.loc["IN"]
# Out:
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# on_earth           True
# density         380.826
# Name: IN, dtype: object

# %%
# TO DO: Use .iloc to print the values from all columns from 3rd row (index number will be 1 less than the row number).
brics.iloc[2]
# Out:
# country           India
# population         1252
# area            3287590
# capital       New Delhi
# on_earth           True
# density         380.826
# Name: IN, dtype: object

# %% [markdown]
# # Adding rows in the dataframe
#
# append() is used to add records in a dataframe or even in lists.

# %%
# adding a new row using append
newrow={'code':'WK','country':'Wakanda','population':5,'area':1000000,'capital':'Wakanda City','on_earth':False,'density':5}
brics1=brics.append(newrow,ignore_index=True)

# %%
brics1
# Out:
#         country  population      area       capital  on_earth     density code
# 0        Brazil         200   8515767      Brasilia      True   23.485847  NaN
# 1        Russia         144  17098242        Moscow      True    8.421918  NaN
# 2         India        1252   3287590     New Delhi      True  380.826076  NaN
# 3         China        1357   9596961       Beijing      True  141.398928  NaN
# 4  South Africa          55   1221037      Pretoria      True   45.043680  NaN
# 5       Wakanda           5   1000000  Wakanda City     False    5.000000   WK

# %%
#Adding a new row using .loc
brics.loc['WK'] = ['Wakanda', 5, 1000000, 'Wakanda City', False, 5]   
# Sequence is very important. Data types may get changed due to wrong sequence.
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000

# %%
# TO DO: Add a new row in the dataframe using .loc any other country with some values in all columns.
brics.loc['IY']=["Italy",100,2000000,"Rome",True,30]
brics
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# IY           Italy         100   2000000          Rome      True   30.000000

# %%
# Fetching the value in 2-D way. In Excel, we have cells for that, Ex- A2 means column A and row 2.
brics.loc["IN","capital"]
# Out:
# 'New Delhi'

# %%
brics["capital"].loc["IN"]
# Out:
# 'New Delhi'

# %%
brics.loc["IN"]['capital']
# Out:
# 'New Delhi'

# %% [markdown]
# #### Deleting rows and columns from a dataframe using drop()

# %%
# Lets create a new dataframe so that brics is not affected.
brics1 = brics
brics1
# Out:
#            country  population      area       capital  on_earth     density
# code
# BR          Brazil         200   8515767      Brasilia      True   23.485847
# RU          Russia         144  17098242        Moscow      True    8.421918
# IN           India        1252   3287590     New Delhi      True  380.826076
# CH           China        1357   9596961       Beijing      True  141.398928
# SA    South Africa          55   1221037      Pretoria      True   45.043680
# WK         Wakanda           5   1000000  Wakanda City     False    5.000000
# IY           Italy         100   2000000          Rome      True   30.000000

# %%
brics1.drop(["area"],axis=1)   # axis = 0 by default for rows. Axis = 1 for column.
# Out:
#            country  population       capital  on_earth     density
# code
# BR          Brazil         200      Brasilia      True   23.485847
# RU          Russia         144        Moscow      True    8.421918
# IN           India        1252     New Delhi      True  380.826076
# CH           China        1357       Beijing      True  141.398928
# SA    South Africa          55      Pretoria      True   45.043680
# WK         Wakanda           5  Wakanda City     False    5.000000
# IY           Italy         100          Rome      True   30.000000

# %%
brics1=brics

# %%
# TO DO: Try deleting area and density columns from brics1 dataframe
brics1.drop(["area","density"], axis=1)
# Out:
#            country  population       capital  on_earth
# code
# BR          Brazil         200      Brasilia      True
# RU          Russia         144        Moscow      True
# IN           India        1252     New Delhi      True
# CH           China        1357       Beijing      True
# SA    South Africa          55      Pretoria      True
# WK         Wakanda           5  Wakanda City     False
# IY           Italy         100          Rome      True

# %%
# TO DO: Delete the record for Wakanda by using its index WK
# Hint: Use WK as identifier and delete axis argument or put axis = 0
brics1=brics
brics1.drop(['WK'], axis=0)
# Out:
#            country  population      area    capital  on_earth     density
# code
# BR          Brazil         200   8515767   Brasilia      True   23.485847
# RU          Russia         144  17098242     Moscow      True    8.421918
# IN           India        1252   3287590  New Delhi      True  380.826076
# CH           China        1357   9596961    Beijing      True  141.398928
# SA    South Africa          55   1221037   Pretoria      True   45.043680
# IY           Italy         100   2000000       Rome      True   30.000000

# %%
brics1 = brics
# Another way to drop columns
brics1.drop(columns=['area', 'density'])
# Out:
#            country  population       capital  on_earth
# code
# BR          Brazil         200      Brasilia      True
# RU          Russia         144        Moscow      True
# IN           India        1252     New Delhi      True
# CH           China        1357       Beijing      True
# SA    South Africa          55      Pretoria      True
# WK         Wakanda           5  Wakanda City     False
# IY           Italy         100          Rome      True

# %%
brics1 = brics
# Drop rows by index
brics1.drop(['IN', 'CH'])
# Out:
#            country  population      area       capital  on_earth    density
# code
# BR          Brazil         200   8515767      Brasilia      True  23.485847
# RU          Russia         144  17098242        Moscow      True   8.421918
# SA    South Africa          55   1221037      Pretoria      True  45.043680
# WK         Wakanda           5   1000000  Wakanda City     False   5.000000
# IY           Italy         100   2000000          Rome      True  30.000000

# %%
#The shape function helps us to find the shape or size of an array or matrix. In Excel - A1:D10.  
# shape[0] means we are working along the first dimension of your array.
# If Y has n rows and m columns, then Y.shape is (n,m). So Y.shape[0] is n.
for index in range(brics.shape[0]):
    countryName=brics.iloc[index,0]   #row- index, column=0
    cityName=brics.iloc[index,3]     #row- index, column=3
    print("The capital city of",countryName,"is",cityName)
# Out:
# The capital city of Brazil is Brasilia
# The capital city of Russia is Moscow
# The capital city of India is New Delhi
# The capital city of China is Beijing
# The capital city of South Africa is Pretoria
# The capital city of Wakanda is Wakanda City
# The capital city of Italy is Rome

# %%
#Another solution
for index in range(brics.shape[0]):
    print("The capital city of",brics.iloc[index,0],"is",brics.iloc[index,3])
# Out:
# The capital city of Brazil is Brasilia
# The capital city of Russia is Moscow
# The capital city of India is New Delhi
# The capital city of China is Beijing
# The capital city of South Africa is Pretoria
# The capital city of Wakanda is Wakanda City
# The capital city of Italy is Rome

# %%
#Another solution
# iterrows() is a generator that iterates over the rows of the dataframe and returns the index of each row, 
# in addition to an object containing the row itself.
for index, row in brics.iterrows():
    print("The capital city of",row["country"],"is",row["capital"])
# Out:
# The capital city of Brazil is Brasilia
# The capital city of Russia is Moscow
# The capital city of India is New Delhi
# The capital city of China is Beijing
# The capital city of South Africa is Pretoria
# The capital city of Wakanda is Wakanda City
# The capital city of Italy is Rome

# %% [markdown]
# ## Importing data from an URL

# %%
import io

# %%
cars=pd.read_csv("C:/Users/srish/Downloads/cars.csv")    #loading the dataset
cars
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
# Print top 5 rows from the data, without any sorting or filter.
cars.head()
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True

# %%
# TO DO: Print top 7 rows from the data
cars.head(7)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
# For bottom 5 rows in the dataframe
cars.tail()
# Out:
#   Unnamed: 0  cars_per_cap  country  drives_right
# 2        JAP           588    Japan         False
# 3         IN            18    India         False
# 4         RU           200   Russia          True
# 5        MOR            70  Morocco          True
# 6         EG            45    Egypt          True

# %%
# TO DO: Print last 10 rows from the dataframe
cars.tail(10)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True

# %%
# Giving a name to the unnamed column

print(cars)
df1=cars.rename(columns={'Unnamed: 0':'code'}, inplace=False)
print(df1)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True
# 5        MOR            70        Morocco          True
# 6         EG            45          Egypt          True
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True

# %%
cars.rename(columns={'Unnamed: 0':'code'}, inplace=True)
print(cars)
# Out:
#   code  cars_per_cap        country  drives_right
# 0   US           809  United States          True
# 1  AUS           731      Australia         False
# 2  JAP           588          Japan         False
# 3   IN            18          India         False
# 4   RU           200         Russia          True
# 5  MOR            70        Morocco          True
# 6   EG            45          Egypt          True

# %%
print(cars["cars_per_cap"])    #Print without column name at top
# Out:
# 0    809
# 1    731
# 2    588
# 3     18
# 4    200
# 5     70
# 6     45
# Name: cars_per_cap, dtype: int64

# %%
print(cars[["cars_per_cap"]])
# Out:
#    cars_per_cap
# 0           809
# 1           731
# 2           588
# 3            18
# 4           200
# 5            70
# 6            45

# %%
# TO DO: Read the data again and set the 1st column as the index column. Then, print the cars dataframe.
cars=pd.read_csv("C:/Users/srish/Downloads/cars.csv",index_col=0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# TO DO : Print the details of RU
cars.loc["RU"]
# Out:
# cars_per_cap       200
# country         Russia
# drives_right      True
# Name: RU, dtype: object

# %%
#TO DO: Can you change the above answer to show the column name at the top? 
cars.loc[["RU"]]
# Out:
#     cars_per_cap country  drives_right
# RU           200  Russia          True

# %%
# TO DO: Print all details for RU and AUS from cars dataframe.
cars.iloc[[1,4]]
# Out:
#      cars_per_cap    country  drives_right
# AUS           731  Australia         False
# RU            200     Russia          True

# %%
# Print the Cars Per Capita (cars_per_cap) for India (IN).
cars.loc["IN"]["cars_per_cap"]
# Out:
# 18

# %%
# Print the Cars Per Capita (cars_per_cap) for India (IN) and Russia (RU).
cars.loc[["IN","RU"]]["cars_per_cap"]
# Out:
# IN     18
# RU    200
# Name: cars_per_cap, dtype: int64

# %%
# Print the Cars Per Capita and Country name for India and Russia
cars.iloc[[3,4]][["cars_per_cap","country"]]
# Out:
#     cars_per_cap country
# IN            18   India
# RU           200  Russia

# %% [markdown]
# # Pandas Advanced and Matplotlib

# %%
marks=pd.read_csv("C:/Users/srish/Downloads/marks.csv")

# %%
marks
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
# TO DO: Show the shape of the dataframe
marks.shape
# Out:
# (20, 7)

# %%
# TO DO: Get the information and structure of the data with non-null value counts
marks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      20 non-null     object
#  1   Student_Name    20 non-null     object
#  2   English         20 non-null     float64
#  3   Maths           20 non-null     float64
#  4   Science         20 non-null     float64
#  5   History         20 non-null     float64
#  6   Social_Studies  20 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 1.2+ KB

# %%
# Print datatypes of the each column
marks.dtypes
# Out:
# Student_ID         object
# Student_Name       object
# English           float64
# Maths             float64
# Science           float64
# History           float64
# Social_Studies    float64
# dtype: object

# %%
print(type(marks))
print(type(marks.English))  # Column's dtype is Series, the dtype of the values is Object.
print(type(5))
print(type(5.5))
print(type("Python"))
print(type(True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
print(marks)
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
display(marks)
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %%
marks
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 17        7.305670
# 18       83.344403
# 19       82.802787

# %% [markdown]
# ### Using range and multiple values in .loc and .iloc

# %%
num=5
num
# Out:
# 5

# %%
num==6
# Out:
# False

# %%
# selecting marks for 'Ria'
display(marks.loc[marks.Student_Name=="Ria"])
# Out:
#    Student_ID Student_Name    English      Maths   Science    History  \
# 17        S18          Ria  30.830802  25.545682  84.27165  78.727155
#
#     Social_Studies
# 17         7.30567

# %%
# TO DO: Print all records for David
marks.loc[marks.Student_Name=="David"]
# Out:
#   Student_ID Student_Name    English      Maths    Science    History  \
# 3        S04        David  21.160844  95.052971  35.860852  62.865185
#
#    Social_Studies
# 3       95.264572

# %%
# Using OR operator to print details if the name is either 'Ria' OR 'David'
display(marks.loc[(marks.Student_Name == 'Ria') | (marks.Student_Name == 'David')])
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 17        S18          Ria  30.830802  25.545682  84.271650  78.727155
#
#     Social_Studies
# 3        95.264572
# 17        7.305670

# %%
# TO DO: Print all records is the Student ID is either S05 or S10
display(marks.loc[(marks.Student_ID=="S05") | (marks.Student_ID=="S10")])
# Out:
#   Student_ID Student_Name    English      Maths   Science    History  \
# 4        S05       Edward  63.250994  60.693247  7.020915  60.505272
# 9        S10         John  30.968731  14.282925  3.312853  79.916094
#
#    Social_Studies
# 4       34.041671
# 9       32.706891

# %%
# TO DO: Fetch all details where marks in English > 70 or marks in Maths > 70.
display(marks.loc[(marks.English >70) | (marks.Maths >70)])
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 3        95.264572
# 5        85.019761
# 8        90.483635
# 11       71.930382
# 13       20.583259
# 15       74.528425
# 16        8.432155
# 18       83.344403

# %%
# TO DO: Fetch all details where marks in English > 70 AND marks in Maths > 70.
display(marks.loc[(marks.English>70 ) & (marks.Maths>70)])
# Out:
#    Student_ID Student_Name    English      Maths   Science    History  \
# 18        S19        Suvin  72.218179  85.284128  32.55506  47.007177
#
#     Social_Studies
# 18       83.344403

# %%
# TO DO: Fetch all details for all students except for Ria or the all students who are not Ria.
display(marks.loc[marks.Student_Name!="Ria"])
# Out:
#    Student_ID Student_Name    English      Maths    Science    History  \
# 0         S01        Alice  96.874050  15.367999  58.682033  59.690510
# 1         S02          Bob   5.462131  81.032680  83.171957  45.664012
# 2         S03      Charlie  60.753099  65.219548  99.323628  24.281512
# 3         S04        David  21.160844  95.052971  35.860852  62.865185
# 4         S05       Edward  63.250994  60.693247   7.020915  60.505272
# 5         S06        Fysal  42.694748  77.348295  37.216613  33.784399
# 6         S07       George  66.276626  46.812190  14.219533  18.582771
# 7         S08       Hareez   5.302984  11.966929  43.980951  54.410098
# 8         S09         Ivan   5.777530  79.508179  94.559212  38.355867
# 9         S10         John  30.968731  14.282925   3.312853  79.916094
# 10        S11       Kelvin  40.219985  55.325651  16.826141   7.462064
# 11        S12          Lia  95.928421  35.789430  95.440164  43.520213
# 12        S13        Maria   8.215446  25.042783  16.518147  36.543154
# 13        S14         Noel  72.833673   7.160086  22.089014  52.867757
# 14        S15       Oliver   5.982402  16.460926  40.977224  80.925749
# 15        S16        Peter  40.694327  91.395888   8.149884  13.852098
# 16        S17          Roy  43.559963  99.270852  13.924531  71.306738
# 18        S19        Suvin  72.218179  85.284128  32.555060  47.007177
# 19        S20          Tan  18.070264  56.662635   2.618987  14.067349
#
#     Social_Studies
# 0        61.373070
# 1        80.805730
# 2        58.057612
# 3        95.264572
# 4        34.041671
# 5        85.019761
# 6        87.021849
# 7        74.530018
# 8        90.483635
# 9        32.706891
# 10       34.449110
# 11       71.930382
# 12       80.665074
# 13       20.583259
# 14       83.312063
# 15       74.528425
# 16        8.432155
# 18       83.344403
# 19       82.802787

# %%
# Index column can be changed by giving the name of the column - unique and case-sensitive

marks = pd.read_csv('marks.csv', index_col='Student_ID')  # could have given the index no. of the columns (0,1..) as well.
display(marks)
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S13               Maria   8.215446  25.042783  16.518147  36.543154
# S14                Noel  72.833673   7.160086  22.089014  52.867757
# S15              Oliver   5.982402  16.460926  40.977224  80.925749
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891
# S11              34.449110
# S12              71.930382
# S13              80.665074
# S14              20.583259
# S15              83.312063
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[0:10]) # Range of values. Includes all values/labels.
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891

# %%
display(marks.iloc['S04'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-5a62b8c9ef0e> in <module>
# ----> 1 display(marks.iloc['S04'])
#
# ~\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1491             key = item_from_zerodim(key)
#    1492             if not is_integer(key):
# -> 1493                 raise TypeError("Cannot index by location index with a non-integer key")
#    1494
#    1495             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %% [markdown]
# ### Since we don't use labels in .iloc , it is showing an error.

# %%
# Correct the issue of the previous code cell and write the correct syntax here.
marks.iloc[3]
# Out:
# Student_Name        David
# English           21.1608
# Maths              95.053
# Science           35.8609
# History           62.8652
# Social_Studies    95.2646
# Name: S04, dtype: object

# %%
# Data of multiple and non-consecuitive indices
# Selecting details of the 1st and 5th row
display(marks.iloc[[0, 4]])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S05              34.041671

# %%
# TO DO: Print the details from 0th, 5th and 8th rows, along with the details of indices 4th, 11th and 16th.
display(marks.iloc[[0,4,7,3,10,15]])
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S04               David  21.160844  95.052971  35.860852  62.865185
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S16               Peter  40.694327  91.395888   8.149884  13.852098
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S05              34.041671
# S08              74.530018
# S04              95.264572
# S11              34.449110
# S16              74.528425

# %%
# .loc can be used to fetch details from a range of index values in a sequence.

display(marks.loc['S01':'S05'])   # Continuous series of the indices based on label.
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[2:5])                #displays all the values for all the columns for indices from 2 to 4
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[0:5])                       #displays all the values for all the columns for indices from 0 to 4
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[:5])                   #displays all the values for all the columns for indices from 0 to 4
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671

# %%
display(marks.iloc[15:20])               #displays all the values for all the columns for indices from 15 to 19
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[15:])           #displays all the values for all the columns for indices from 15 to 19
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[15:100])    #displays all the values for all the columns for indices from 15 to 19
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %%
display(marks.iloc[:])    #displays all the values for all the columns for indices from 0 to 19
# Out:
#            Student_Name    English      Maths    Science    History  \
# Student_ID
# S01               Alice  96.874050  15.367999  58.682033  59.690510
# S02                 Bob   5.462131  81.032680  83.171957  45.664012
# S03             Charlie  60.753099  65.219548  99.323628  24.281512
# S04               David  21.160844  95.052971  35.860852  62.865185
# S05              Edward  63.250994  60.693247   7.020915  60.505272
# S06               Fysal  42.694748  77.348295  37.216613  33.784399
# S07              George  66.276626  46.812190  14.219533  18.582771
# S08              Hareez   5.302984  11.966929  43.980951  54.410098
# S09                Ivan   5.777530  79.508179  94.559212  38.355867
# S10                John  30.968731  14.282925   3.312853  79.916094
# S11              Kelvin  40.219985  55.325651  16.826141   7.462064
# S12                 Lia  95.928421  35.789430  95.440164  43.520213
# S13               Maria   8.215446  25.042783  16.518147  36.543154
# S14                Noel  72.833673   7.160086  22.089014  52.867757
# S15              Oliver   5.982402  16.460926  40.977224  80.925749
# S16               Peter  40.694327  91.395888   8.149884  13.852098
# S17                 Roy  43.559963  99.270852  13.924531  71.306738
# S18                 Ria  30.830802  25.545682  84.271650  78.727155
# S19               Suvin  72.218179  85.284128  32.555060  47.007177
# S20                 Tan  18.070264  56.662635   2.618987  14.067349
#
#             Social_Studies
# Student_ID
# S01              61.373070
# S02              80.805730
# S03              58.057612
# S04              95.264572
# S05              34.041671
# S06              85.019761
# S07              87.021849
# S08              74.530018
# S09              90.483635
# S10              32.706891
# S11              34.449110
# S12              71.930382
# S13              80.665074
# S14              20.583259
# S15              83.312063
# S16              74.528425
# S17               8.432155
# S18               7.305670
# S19              83.344403
# S20              82.802787

# %% [markdown]
# # Data cleaning : Empty value treatment in dataframes

# %%
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],  # With strings, it will become 'None'
          "temperature_f":[67.24,84.56,91.61,None,49.64]   #With numbers, it will become 'NaN'
         })
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %%
# To identify the null value. Return true if the value is null otherwise false
temps.isna()
# Out:
#    sequence  measurement_type  temperature_f
# 0     False             False          False
# 1     False             False          False
# 2     False             False          False
# 3     False              True           True
# 4     False             False          False

# %%
# Return the count of missing value from each column     
temps.isna().sum()
# Out:
# sequence            0
# measurement_type    1
# temperature_f       1
# dtype: int64

# %%
# Total count of null from all columns
temps.isna().sum().sum()
# Out:
# 2

# %%
clean_temps=temps.dropna(how="any")
display(clean_temps)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %%
# TO DO:  Copy paste the codes from the above cell, change the 'how' argument as 'all' and observe the difference in output.
clean_temps1=temps.dropna(how="all")
display(clean_temps1)
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4             None            NaN
# 4         5        estimated          49.64

# %% [markdown]
# ### The fourth row is not removed as it has a value in the first column.

# %%
# Drop the ROWS where at least one element is missing.
temps.dropna()
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 4         5        estimated          49.64

# %%
# Drop COLUMNS where there are missing values.

# Drop the columns where at least one element is missing.
temps.dropna(axis = 'columns') # Without the 'axis' argument, rows will be dropped by default as you did in the previous code.
# Out:
#    sequence
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
temps['temperature_f'].cumsum()   # Returns the commulative sum.
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4    293.05
# Name: temperature_f, dtype: float64

# %%
temps['temperature_f'].cumsum(skipna=False)
# Out:
# 0     67.24
# 1    151.80
# 2    243.41
# 3       NaN
# 4       NaN
# Name: temperature_f, dtype: float64

# %%
temps.fillna(value=0, inplace=True)

# %%
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4                0           0.00
# 4         5        estimated          49.64

# %%
# Why 0 in last column is 0.00 while only 0 in measurement_type? Please explain as a comment in this cell.

# %% [markdown]
# ### As all the other values in the last column have a precision of 2 , therefore the value we filled converted to 0.00 from 0 .

# %%
# fill missing value with previous value
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps.fillna(method='pad' , inplace=True)  # 'pad' means padding. Take value from previous row
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4           actual          91.61
# 4         5        estimated          49.64

# %%
# fill missing value with next value
temps1 = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps1.fillna(method='bfill' , inplace=True)  # bfill takes next value to replace
temps1
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual          67.24
# 1         2           actual          84.56
# 2         3           actual          91.61
# 3         4        estimated          49.64
# 4         5        estimated          49.64

# %%
# fill missing value with mean
temps = pd.DataFrame({"sequence":[1,2,3,4,5],
          "measurement_type":['actual','actual','actual',None,'estimated'],
          "temperature_f":[67.24,84.56,91.61,None,49.64]
         })
temps['temperature_f'].fillna(temps['temperature_f'].mean(), inplace=True)  # Mean will not work on strings
temps
# Out:
#    sequence measurement_type  temperature_f
# 0         1           actual        67.2400
# 1         2           actual        84.5600
# 2         3           actual        91.6100
# 3         4             None        73.2625
# 4         5        estimated        49.6400

# %% [markdown]
# # Lambda Function

# %%
# lambda is used to define a temporary expression without any return statement. It always contains an expression
# that is returned. There is no need to assign a variable with lambda.
def cube(y):
    return y*y*y    #return is a keyword. Python stops when the code reaches to return statement. Print is a function.
# using the normally defined function
    print(cube(5))
    
# using the lambda function               
lambda_cube = lambda y: y*y*y
print(lambda_cube(5))
# Out:
# 125

# %%
teams = pd.DataFrame({"Region":['North','West','East','South'],
          "Team":['One','Two','One','Two'],
          "Squad":['A','B','C','D'],
          "Revenue":[7500,5500,2750,6400],
            "Cost":[5200,5100,4400,5300]})

display (teams)
# Out:
#   Region Team Squad  Revenue  Cost
# 0  North  One     A     7500  5200
# 1   West  Two     B     5500  5100
# 2   East  One     C     2750  4400
# 3  South  Two     D     6400  5300

# %%
# apply() to alter values along an axis in your dataframe or in a series/column 
#Categorise based on the revenue and cost

teams["Profit"]=teams.apply(lambda x: "Profit" if x["Revenue"]> x["Cost"] else "Loss", axis=1)
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit
# 0  North  One     A     7500  5200  Profit
# 1   West  Two     B     5500  5100  Profit
# 2   East  One     C     2750  4400    Loss
# 3  South  Two     D     6400  5300  Profit

# %%
# Use map() to substitute each value in a series
team_map = {"One":"Red","Two":"Blue"}      # new variable - dictionary (key-value pair)
teams['Team Color'] = teams['Team'].map(team_map) # A new column with mapped values
teams
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue

# %%
# applymap() method do elementwise operation on the entire dataframe.
# This method applies a function that accepts and returns a scalar to every element of a DataFrame.

teams.applymap(lambda x: len(str(x)))  # int(x) won't work because data has strings which can not be convereted to int.
# Out:
#    Region  Team  Squad  Revenue  Cost  Profit  Team Color
# 0       5     3      1        4     4       6           3
# 1       4     3      1        4     4       6           4
# 2       4     3      1        4     4       4           3
# 3       5     3      1        4     4       6           4

# %%
# Grouping on different categories. Needs the category as well as parameter
teams.groupby(['Profit']).max()
# Out:
#        Region Team Squad  Revenue  Cost Team Color
# Profit
# Loss     East  One     C     2750  4400        Red
# Profit   West  Two     D     7500  5300        Red

# %%
# TO DO: Can you group the records on Cost with minimum values?
teams.groupby(["Cost"]).min()
# Out:
#      Region Team Squad  Revenue  Profit Team Color
# Cost
# 4400   East  One     C     2750    Loss        Red
# 5100   West  Two     B     5500  Profit       Blue
# 5200  North  One     A     7500  Profit        Red
# 5300  South  Two     D     6400  Profit       Blue

# %%
# TO DO: Can you group the records on Revenue column with mean values?
teams.groupby(["Revenue"]).mean()
# Out:
#          Cost
# Revenue
# 2750     4400
# 5500     5100
# 6400     5300
# 7500     5200

# %%
#Grouping on the basis of aggregates
teams.groupby(['Team']).agg({'Revenue':['mean','min','max']})
# Out:
#      Revenue
#         mean   min   max
# Team
# One     5125  2750  7500
# Two     5950  5500  6400

# %%
# Setting two columns as index when a single column has not unique values.

teams_reindex = teams.set_index(['Region','Team'])  # 2 indices. useful when values are not unique
display(teams)

print()    # TO print blank/new line.


display(teams_reindex)
# Out:
#   Region Team Squad  Revenue  Cost  Profit Team Color
# 0  North  One     A     7500  5200  Profit        Red
# 1   West  Two     B     5500  5100  Profit       Blue
# 2   East  One     C     2750  4400    Loss        Red
# 3  South  Two     D     6400  5300  Profit       Blue
#             Squad  Revenue  Cost  Profit Team Color
# Region Team
# North  One      A     7500  5200  Profit        Red
# West   Two      B     5500  5100  Profit       Blue
# East   One      C     2750  4400    Loss        Red
# South  Two      D     6400  5300  Profit       Blue

# %%
# Restructuring the dataframe based the multiple indices
stacked = pd.DataFrame(teams_reindex.stack())
stacked
# Out:
#                              0
# Region Team
# North  One  Squad            A
#             Revenue       7500
#             Cost          5200
#             Profit      Profit
#             Team Color     Red
# West   Two  Squad            B
#             Revenue       5500
#             Cost          5100
#             Profit      Profit
#             Team Color    Blue
# East   One  Squad            C
#             Revenue       2750
#             Cost          4400
#             Profit        Loss
#             Team Color     Red
# South  Two  Squad            D
#             Revenue       6400
#             Cost          5300
#             Profit      Profit
#             Team Color    Blue

# %% [markdown]
# # Merging dataframes

# %%
# Defining two new dataframes
group1 = pd.DataFrame({'name': ['Alice', 'Bob', 'Charlie', 'David'],
                    'number': [1, 2, 3, 4]})
group2 = pd.DataFrame({'name': ['Charlie', 'David', 'Edward', 'Ford'],
                    'number': [3, 4, 5, 6]})
display(group1)
display(group2)
# Out:
#       name  number
# 0    Alice       1
# 1      Bob       2
# 2  Charlie       3
# 3    David       4
#       name  number
# 0  Charlie       3
# 1    David       4
# 2   Edward       5
# 3     Ford       6

# %%
group1.merge(group2,how='left', on='number')   # Left - all from 1st table and only common from 2nd table.

# Notice the NAN or empty values.
# Out:
#     name_x  number   name_y
# 0    Alice       1      NaN
# 1      Bob       2      NaN
# 2  Charlie       3  Charlie
# 3    David       4    David

# %%
group1.merge(group2)
# Out:
#       name  number
# 0  Charlie       3
# 1    David       4

# %%
group1.merge(group2,how="inner",left_on="number", right_on="number")   # Inner - Shows only the common records
# Out:
#     name_x  number   name_y
# 0  Charlie       3  Charlie
# 1    David       4    David

# %%
# Why there are no null values now in the output? Answer as a comment.

# %% [markdown]
# ###  Since only the common records are shown when we use inner, therefore, we don't get null values as only the common values from group1 and group2  are shown.

# %%
group1.merge(group2, how="right", left_on="number", right_on="number")
# Out:
#     name_x  number   name_y
# 0  Charlie       3  Charlie
# 1    David       4    David
# 2      NaN       5   Edward
# 3      NaN       6     Ford

# %% [markdown]
# #  Matplotlib library in Python

# %%
# We have already imported matplot library in the first cell

# %%
mtc=pd.read_csv("C:/Users/srish/Downloads/mtcars.csv")
mtc
# Out:
#               car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0      4     4
# 1      4     4
# 2      4     1
# 3      3     1
# 4      3     2
# 5      3     1
# 6      3     4
# 7      4     2
# 8      4     2
# 9      4     4
# 10     4     4
# 11     3     3
# 12     3     3
# 13     3     3
# 14     3     4
# 15     3     4
# 16     3     4
# 17     4     1
# 18     4     2
# 19     4     1
# 20     3     1
# 21     3     2
# 22     3     2
# 23     3     4
# 24     3     2
# 25     4     1
# 26     5     2
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
# TO DO : Create a scatter plot with mpg and hp by providing xlabel and ylabel
mtc.plot(kind="scatter",x="mpg",y="hp")
plt.show()

# %%
# TO DO: Change the color to red in the previous code
mtc.plot(kind="scatter",x="mpg",y="hp",color="red")
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='hp'>

# %%
# TO DO: Create crosstab for cyl(cylinder) and columns as count
import seaborn as sns
import numpy as np
ct=pd.crosstab(mtc.cyl,mtc.cyl)
ct.plot.bar(stacked=True)
plt.legend(title="mark")
plt.show()

# %%
# TO DO: Create crosstab for cyl(cylinder) and am as 'ct2' and create a bar plot
ct2=pd.crosstab(mtc.cyl,mtc.am)
ct2.plot.bar(stacked=False)
plt.legend()
plt.show()

# %%
# TO DO: Create groupby (cyl) to visualize mpg and hp in a bar chart
mtc.groupby("cyl")[["mpg","hp"]].nunique().plot(kind="bar")
plt.show()

# %%
# TO DO: Create a pie chart for cyl count
plt.pie(mtc["cyl"].unique(), labels=mtc["cyl"].unique())
plt.legend()
plt.show()

# %%
# TO DO: Create a Histogram for MPG column
plt.hist(mtc["mpg"])
plt.show()

# %% [markdown]
# # Thank You
